# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from selenium.webdriver.common.keys import Keys
import time
import re
from tqdm.notebook import tqdm

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime ,timedelta , date

# %% [markdown]
# # REASON

# %%
browser_path = "/Users/boo/USA_President_Election/chromedriver.exe"
driver = webdriver.Chrome(browser_path)

time.sleep(2)

# %%
data=pd.DataFrame()
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
link_html = soup.select("body > div.wrap > div > main > div > div:nth-child(2) > div") 

driver.get('https://reason.com/category/politics/elections/election-2024/')
time.sleep(2)

html = driver.page_source
soup = BeautifulSoup(html,'lxml')
articles = soup.select('body > div.wrap > div > main > div > div:nth-child(2) > div')[0].select('article')

news = [ {'headlines':article.select('div.rcom-list-content--article-content > h4 > a')[0].text,
          'date':article.select('div.rcom-list-content--article-content > p.meta > time'),
          'Press':'reason',
          'Link':article.select('div.rcom-list-content--article-content > h4 > a')[0].attrs['href'],
          'category':article.select('div.rcom-list-content--article-content > p.rcom-list-content--article-tag.tag > a')[0].text.strip()
         } for article in articles]

news_df = pd.DataFrame(news)
data = pd.concat([data,news_df])

# %%
data
# Out:
#                                              headlines  \
# 0    Compendium of Writings About the 2024 Election...
# 1               Newspaper Endorsements Die in Daylight
# 2    Dave Smith, David Stockman, and Jacob Grier: W...
# 3     Live On Election Eve With The Reason Roundtable!
# 4             To Get Through the Election, Use Ozempic
# ..                                                 ...
# 187  Israelis and Palestinians Found Common Ground ...
# 188                                Thank God It's Over
# 189  Democrats Are Talking About 'Freedom' Because ...
# 190      Jane Coaston: What Is 'Freedom' to Democrats?
# 191                               Tim Walz Keeps Lying
#
#                         date   Press  \
# 0     [[10.31.2024 4:49 PM]]  reason
# 1     [[10.31.2024 1:53 PM]]  reason
# 2     [[10.31.2024 1:00 PM]]  reason
# 3    [[10.31.2024 11:15 AM]]  reason
# 4     [[10.30.2024 4:00 PM]]  reason
# ..                       ...     ...
# 187   [[8.23.2024 10:30 AM]]  reason
# 188    [[8.23.2024 9:30 AM]]  reason
# 189   [[8.22.2024 10:20 PM]]  reason
# 190    [[8.22.2024 3:50 PM]]  reason
# 191    [[8.22.2024 2:26 PM]]  reason
#
#                                                   Link  \
# 0    https://reason.com/volokh/2024/10/31/compendiu...
# 1    https://reason.com/2024/10/31/newspaper-endors...
# 2    https://reason.com/podcast/2024/10/31/dave-smi...
# 3    https://reason.com/podcast/2024/10/31/live-on-...
# 4    https://reason.com/2024/10/30/to-get-through-t...
# ..                                                 ...
# 187  https://reason.com/2024/08/23/israelis-and-pal...
# 188  https://reason.com/2024/08/23/thank-god-its-over/
# 189  https://reason.com/2024/08/22/democrats-are-ta...
# 190  https://reason.com/podcast/2024/08/22/jane-coa...
# 191  https://reason.com/2024/08/22/tim-walz-keeps-l...
#
#                        category
# 0                 Election 2024
# 1               Media Criticism
# 2                 Election 2024
# 3                 Election 2024
# 4                 Election 2024
# ..                          ...
# 187  Democratic Convention 2024
# 188  Democratic Convention 2024
# 189               Election 2024
# 190               Election 2024
# 191                    Tim Walz
#
# [192 rows x 5 columns]

# %%
body_text_list=[]
for url in data['Link']:

    driver.get(url)
    time.sleep(2)

    html = driver.page_source
    soup = BeautifulSoup(html,'lxml')
    body = soup.select('body > div.wrap > div > main > div > div.article-row > div.article-body.col-sm-10.offset-sm-1.col-md-8.offset-md-2.offset-lg-0 > article > div')
    body_text = ''.join([p.text for p in body[0].select('p')])
    body_text_list.append(body_text)
    
data['text'] = pd.Series(body_text_list)

# %%
data
# Out:
#                                              headlines  \
# 0    Compendium of Writings About the 2024 Election...
# 1               Newspaper Endorsements Die in Daylight
# 2    Dave Smith, David Stockman, and Jacob Grier: W...
# 3     Live On Election Eve With The Reason Roundtable!
# 4             To Get Through the Election, Use Ozempic
# ..                                                 ...
# 187  Israelis and Palestinians Found Common Ground ...
# 188                                Thank God It's Over
# 189  Democrats Are Talking About 'Freedom' Because ...
# 190      Jane Coaston: What Is 'Freedom' to Democrats?
# 191                               Tim Walz Keeps Lying
#
#                         date   Press  \
# 0     [[10.31.2024 4:49 PM]]  reason
# 1     [[10.31.2024 1:53 PM]]  reason
# 2     [[10.31.2024 1:00 PM]]  reason
# 3    [[10.31.2024 11:15 AM]]  reason
# 4     [[10.30.2024 4:00 PM]]  reason
# ..                       ...     ...
# 187   [[8.23.2024 10:30 AM]]  reason
# 188    [[8.23.2024 9:30 AM]]  reason
# 189   [[8.22.2024 10:20 PM]]  reason
# 190    [[8.22.2024 3:50 PM]]  reason
# 191    [[8.22.2024 2:26 PM]]  reason
#
#                                                   Link  \
# 0    https://reason.com/volokh/2024/10/31/compendiu...
# 1    https://reason.com/2024/10/31/newspaper-endors...
# 2    https://reason.com/podcast/2024/10/31/dave-smi...
# 3    https://reason.com/podcast/2024/10/31/live-on-...
# 4    https://reason.com/2024/10/30/to-get-through-t...
# ..                                                 ...
# 187  https://reason.com/2024/08/23/israelis-and-pal...
# 188  https://reason.com/2024/08/23/thank-god-its-over/
# 189  https://reason.com/2024/08/22/democrats-are-ta...
# 190  https://reason.com/podcast/2024/08/22/jane-coa...
# 191  https://reason.com/2024/08/22/tim-walz-keeps-l...
#
#                        category  \
# 0                 Election 2024
# 1               Media Criticism
# 2                 Election 2024
# 3                 Election 2024
# 4                 Election 2024
# ..                          ...
# 187  Democratic Convention 2024
# 188  Democratic Convention 2024
# 189               Election 2024
# 190               Election 2024
# 191                    Tim Walz
#
#                                                   text
# 0    As election day approaches, here are links to ...
# 1    It sure has been a banner week for the triple ...
# 2    HD Video DownloadIs this the most important el...
# 3    Will Election 2024 result in an orderly transf...
# 4    The two major party candidates provide ample r...
# ..                                                 ...
# 187  Rachel Goldberg and Jon Polin came to the Demo...
# 188  That was all right, I guess. Vice President Ka...
# 189  It will be no tremendously deep insight to poi...
# 190  HD Video DownloadHow do Democrats define "free...
# 191  For Tim Walz, in vitro fertilization (IVF) is ...
#
# [192 rows x 6 columns]

# %%
data.to_csv('reason.csv',index=False)

# %% [markdown]
# # CBS

# %%
def cbs_news(page_num):
    
    content=[]
    title=[]
    date=[]
    
    browser_path = "/Users/boo/USA_President_Election/chromedriver.exe"
    driver = webdriver.Chrome(browser_path)
    time.sleep(2)
    
    for i in range(1,page_num+1):
        
        driver.get(f'https://www.cbsnews.com/feature/election-2024/{i}/')
        time.sleep(2)

        html = driver.page_source
        soup = BeautifulSoup(html, "lxml")
        soup=soup.select('div.col-8.nocontent')[0].select('section')
        
        try:
            for j in range(1,26): #26

                title.append(soup[0].select('h4.item__hed')[j-1].text.strip())
                date.append(soup[0].select('ul.item__metadata')[j-1].text.strip())

                driver.find_element_by_xpath(f'//*[@id="component-election-2024"]/div/article[{j}]').click()
                time.sleep(2)

                html_content = driver.page_source
                soup_content = BeautifulSoup(html_content, "lxml")

                lis=soup_content.select('article')[0].select('p')

                if lis[0].text.strip()[:2]=='By':
                    con=''
                    for k in lis[2:]:
                        con+=k.text.strip() 

                else:
                    con=''
                    for k in lis:
                        con+=k.text.strip()


                content.append(con)
                driver.back()
                time.sleep(2)
        except:
            pass
    df=pd.DataFrame({'title':title,'date':date,'Press':'cbs','content':content})
    return df

# %%
data=cbs_news(14)

# %%
data
# Out:
#                                                  title     date Press  \
# 0            Harris campaign leans into her HBCU roots   4H ago   cbs
# 1    Arizona counties invest millions to reassure v...   7H ago   cbs
# 2    Alito denies Cornel West bid for intervention ...   9H ago   cbs
# 3    Walz's closing campaign message to air on "The...  10H ago   cbs
# 4    Trump's wealth slumps by $1.9 billion amid DJT...  14H ago   cbs
# ..                                                 ...      ...   ...
# 345  Zuckerberg vows to resist federal efforts to i...   Aug 27   cbs
# 346  Dems sue over Georgia rules they say could blo...   Aug 27   cbs
# 347  Texas AG raids Latino Democrats' homes, includ...   Aug 26   cbs
# 348  More than 200 former Bush, McCain and Romney s...   Aug 26   cbs
# 349  H.R. McMaster hopes to "inoculate" Trump from ...   Aug 26   cbs
#
#                                                content
# 0    Howard University is where Vice President Kama...
# 1    Flagstaff, Arizona — Laura Huenneke, secretary...
# 2    Washington — Justice Samuel Alito on Thursday ...
# 3    Minnesota Gov. Tim Walz, the Democratic vice p...
# 4    Updated on:  October 31, 2024 / 4:56 PM EDT\n ...
# ..                                                 ...
# 345  Updated on:  August 27, 2024 / 9:42 AM EDT\n  ...
# 346  Updated on:  August 28, 2024 / 9:17 AM EDT\n  ...
# 347  The nation's oldest Latino civil rights organi...
# 348  Washington — More than 200 Republicans who wor...
# 349  Lt. Gen. H.R. McMaster, who served as a nation...
#
# [350 rows x 4 columns]

# %%
data.to_csv('cbs.csv',index=False)

# %% [markdown]
# # NPR

# %%
driver = webdriver.Chrome("/Users/boo/USA_President_Election/chromedriver")
driver.get("https://www.npr.org/sections/elections/")

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
link_html = soup.select("div.item-info-wrap > div > h2 > a") 
links = []
for link in link_html:
    links.append(link.get('href'))

# %%
df = []   

for link in links:
    driver.get(link)
    time.sleep(2)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    try : 
        title = soup.select("#main-section > article > div.storytitle > h1")[0].text # 기사제목
        date = soup.select("#story-meta > div.story-meta__one > div > div.dateblock > time > span")[0].text # 기사 날짜

        textall = soup.select("#storytext > p") # 기사 내용

        text = []
        for t in textall :
            text.append(t.text)
            
        topic = soup.select("#main-section > article > div.slug-wrap > h3 > a")[0].text # 주제

    except:
        pass

    article = {"Date" : date , "Press" : "NPR", "Topic": topic, "Title": title, "Text" : text} # 합치기 
    df.append(article)

# %%
df=pd.DataFrame(df)

# %%
df.tail()
# Out:
#                           Date Press          Topic  \
# 307    Updated August 29, 2024   NPR  2024 Election
# 308  Updated September 3, 2024   NPR       National
# 309            August 28, 2024   NPR  2024 Election
# 310            August 27, 2024   NPR            Law
# 311            August 27, 2024   NPR       Politics
#
#                                                  Title  \
# 307  Harris is on a 2-day Georgia bus tour. It’s th...
# 308  Weird. Why the popular campaign insult stings ...
# 309  Florida felons could get a bit more clarity on...
# 310  Jack Smith files superseding indictment agains...
# 311    Harris needs Gen Z. Here's her plan to win them
#
#                                                   Text
# 307  [Vice President Harris and her running mate, T...
# 308  [FALCON HEIGHTS, Minn. — Weird. It’s a descrip...
# 309  [Election officials in Florida say they are wo...
# 310  [Prosecutors filed a superseding indictment in...
# 311  [Vice President Harris is bolstering her outre...

# %%
df.to_csv('npr.csv',index=False)

# %% [markdown]
# reason, cbs, npr로 확인하기
